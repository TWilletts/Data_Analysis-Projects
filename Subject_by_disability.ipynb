# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

# %%
data = pd.read_csv(r"C:\Users\Tom\Downloads\table-56.csv")

# %%
data
# Out:
#       CAH level marker          CAH level subject Level of qualification  \
# 0          CAH level 1  01 Medicine and dentistry                    All
# 1          CAH level 1  01 Medicine and dentistry                    All
# 2          CAH level 1  01 Medicine and dentistry                    All
# 3          CAH level 1  01 Medicine and dentistry                    All
# 4          CAH level 1  01 Medicine and dentistry                    All
# ...                ...                        ...                    ...
# 12130      CAH level 3                      Total      All undergraduate
# 12131      CAH level 3                      Total      All undergraduate
# 12132      CAH level 3                      Total      All undergraduate
# 12133      CAH level 3                      Total      All undergraduate
# 12134      CAH level 3                      Total      All undergraduate
#
#       Mode of study Academic Year           Disability marker  Number
# ...

# %%
for i in range(len(data)):
    if data['CAH level marker'][i] != 'CAH level 1':
        data = data.drop(labels=i, axis=0)
    else:
        pass
data.reset_index(drop=True, inplace=True)

# %%
for i in range(len(data)):
    if data['Mode of study'][i] != 'All':
        data = data.drop(labels=i, axis=0)
    else:
        pass
data.reset_index(drop=True, inplace=True)

# %%
for i in range(len(data)):
    if data['Level of qualification'][i] != 'All':
        data = data.drop(labels=i, axis=0)
    else:
        pass
data.reset_index(drop=True, inplace=True)

# %%
no_disability_list = []
disability_list = []
Percent = []
for i in range(27):
    Percent.append(data.Number[(i*3)+2]/data.Number[(i*3)])
    Percent.append(data.Number[(i*3)+2]/data.Number[(i*3)])
    Percent.append(data.Number[(i*3)+2]/data.Number[(i*3)])

# %%
data['Percent'] = Percent

# %%
data
# Out:
#    CAH level marker               CAH level subject Level of qualification  \
# 0       CAH level 1       01 Medicine and dentistry                    All
# 1       CAH level 1       01 Medicine and dentistry                    All
# 2       CAH level 1       01 Medicine and dentistry                    All
# 3       CAH level 1  02 Subjects allied to medicine                    All
# 4       CAH level 1  02 Subjects allied to medicine                    All
# ..              ...                             ...                    ...
# 76      CAH level 1   Total non-science CAH level 1                    All
# 77      CAH level 1   Total non-science CAH level 1                    All
# 78      CAH level 1                           Total                    All
# 79      CAH level 1                           Total                    All
# 80      CAH level 1                           Total                    All
#
# ...

# %%
for i in range(len(data)):
    if data['CAH level subject'].str.get(0)[i] == '0':
        data['CAH level subject'][i] = data['CAH level subject'].str[3:][i]
    elif data['CAH level subject'].str.get(0)[i] == '1':
        data['CAH level subject'][i] = data['CAH level subject'].str[3:][i]
    elif data['CAH level subject'].str.get(0)[i] == '2':
        data['CAH level subject'][i] = data['CAH level subject'].str[3:][i]
    else:
        pass
# Out:
# C:\Users\Tom\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\Tom\anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# C:\Users\Tom\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
for i in range(len(data)):
    if data['CAH level subject'][i] == 'Humanities and liberal arts (non-specific)':
        data['CAH level subject'][i] = 'Humanities & liberal arts'
    elif data['CAH level subject'][i] == 'Agriculture, food and related studies':
        data['CAH level subject'][i] = 'Agriculture'
    elif data['CAH level subject'][i] == 'Geographical and environmental studies (social sciences)':
        data['CAH level subject'][i] = 'Geography (social)'
    elif data['CAH level subject'][i] == 'Geographical and environmental studies (natural sciences)':
        data['CAH level subject'][i] = 'Geography (natural)'
    elif data['CAH level subject'][i] == 'Language and area studies':
        data['CAH level subject'][i] = 'Language studies'
    elif data['CAH level subject'][i] == 'Subjects allied to medicine':
        data['CAH level subject'][i] = 'Allied to medicine'
    elif data['CAH level subject'][i] == 'Education and teaching':
        data['CAH level subject'][i] = 'Education & teaching'
    elif data['CAH level subject'][i] == 'Creative arts and design':
        data['CAH level subject'][i] = 'Creative arts & design'
    elif data['CAH level subject'][i] == 'Communications and media':
        data['CAH level subject'][i] = 'Communications & media'
    elif data['CAH level subject'][i] == 'Historical, philosophical and religious studies':
        data['CAH level subject'][i] = 'History, philosophy & R.E.'   
    elif data['CAH level subject'][i] == 'Architecture, building and planning':
        data['CAH level subject'][i] = 'Architecture'   
    elif data['CAH level subject'][i] == 'Business and management':
        data['CAH level subject'][i] = 'Business'    
    elif data['CAH level subject'][i] == 'Combined and general studies':
        data['CAH level subject'][i] = 'General studies'  
    elif data['CAH level subject'][i] == 'General and others in sciences':
        data['CAH level subject'][i] = 'General sciences'
    elif data['CAH level subject'][i] == 'Biological and sport sciences':
        data['CAH level subject'][i] = 'Sport sciences'
    elif data['CAH level subject'][i] == 'Engineering and technology':
        data['CAH level subject'][i] = 'Engineering'
    elif data['CAH level subject'][i] == 'Medicine and dentistry':
        data['CAH level subject'][i] = 'Medicine & dentistry'
    elif data['CAH level subject'][i] == 'Total':
        data['CAH level subject'][i] = 'Average'
    else:
        pass
# Out:
# C:\Users\Tom\anaconda3\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Tom\anaconda3\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\Tom\anaconda3\lib\site-packages\ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data = data.sort_values(by=['Percent'], ascending=False)

# %%
data
# Out:
#    CAH level marker           CAH level subject Level of qualification  \
# 54      CAH level 1                    Business                    All
# 56      CAH level 1                    Business                    All
# 55      CAH level 1                    Business                    All
# 28      CAH level 1                 Engineering                    All
# 27      CAH level 1                 Engineering                    All
# ..              ...                         ...                    ...
# 64      CAH level 1  History, philosophy & R.E.                    All
# 63      CAH level 1  History, philosophy & R.E.                    All
# 68      CAH level 1      Creative arts & design                    All
# 67      CAH level 1      Creative arts & design                    All
# 66      CAH level 1      Creative arts & design                    All
#
#    Mode of study Academic Year           Disability marker  Number    Percent
# ...

# %%
total_average = data['Percent'][80]
total_average
# Out:
# 7.796736483195324

# %%
for i in range(len(data)):
    if data['CAH level subject'].str.get(0)[i] == 'T' and data['CAH level subject'].str.get(5)[i] == ' ':
        data = data.drop(labels=i, axis=0)
    else:
        pass
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#    CAH level marker           CAH level subject Level of qualification  \
# 0       CAH level 1                    Business                    All
# 1       CAH level 1                    Business                    All
# 2       CAH level 1                    Business                    All
# 3       CAH level 1                 Engineering                    All
# 4       CAH level 1                 Engineering                    All
# ..              ...                         ...                    ...
# 70      CAH level 1  History, philosophy & R.E.                    All
# 71      CAH level 1  History, philosophy & R.E.                    All
# 72      CAH level 1      Creative arts & design                    All
# 73      CAH level 1      Creative arts & design                    All
# 74      CAH level 1      Creative arts & design                    All
#
#    Mode of study Academic Year           Disability marker  Number    Percent
# ...

# %%
total_data = data

# %%
for i in range(len(total_data)):
    if total_data['Disability marker'][i] != 'Total':
        total_data = total_data.drop(labels=i, axis=0)
    else:
        pass
total_data.reset_index(drop=True, inplace=True)

# %%
total_data
# Out:
#    CAH level marker           CAH level subject Level of qualification  \
# 0       CAH level 1                    Business                    All
# 1       CAH level 1                 Engineering                    All
# 2       CAH level 1       Mathematical sciences                    All
# 3       CAH level 1                Architecture                    All
# 4       CAH level 1        Medicine & dentistry                    All
# 5       CAH level 1        Education & teaching                    All
# 6       CAH level 1                         Law                    All
# 7       CAH level 1                   Computing                    All
# 8       CAH level 1                     Average                    All
# 9       CAH level 1      Communications & media                    All
# 10      CAH level 1             General studies                    All
# 11      CAH level 1          Allied to medicine                    All
# ...

# %%
from matplotlib.pyplot import figure

figure(figsize=(45, 25), dpi=80)
x = total_data['CAH level subject']
y = total_data['Percent']
plt.ylabel("Percent of students with disability") 
#threshold = total_average
#plt.axhline(y=threshold,linewidth=1, color='k', ls='--')
bar = plt.bar(x, y, color=['#c98003', '#fdc96e', '#c98003', '#fdc96e', '#c98003', '#fdc96e', '#c98003', '#fdc96e', '#6D1A36', '#c98003', '#fdc96e','#c98003', '#fdc96e','#c98003', '#fdc96e','#c98003', '#fdc96e','#c98003', '#fdc96e','#c98003', '#fdc96e','#c98003', '#fdc96e','#c98003', '#fdc96e'])
plt.xticks(rotation = 90) 
plt.yticks(rotation = 90) 
ax = plt.axes()
ax.set_facecolor("#fffcf8")

matplotlib.rc('font', **font)
plt.show()
# Out:
# C:\Users\Tom\anaconda3\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   if sys.path[0] == '':
